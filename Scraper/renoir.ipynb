# %%
import requests
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait
import re
from lxml.html import fromstring
import json 
import os

# %%
CHROMEDRIVER_PATH = r'C:\Users\Maria\chromedriver\chromedriver.exe'
base_url = 'https://www.cinesrenoir.com'
url = 'https://www.cinesrenoir.com/cine/renoir-floridablanca/cartelera/'

# %%
class Scraper: 
    def __init__(self, url): 
        self.url = url 
    def get_html(self): 
        try: 
            response = requests.get(self.url)
            response.raise_for_status()
        except requests.RequestException: 
            print('A problem occurred with your request')
            raise
        html = fromstring(response.content)
        return html
    def get_all_films(self): 
        results = []
        page = self.get_html()
        page_results = page.findall('.//div[@class="row"]//a')    
        for item in page_results: 
            if 'pelicula' in item.xpath('.//@href')[0]: 
                href = item.xpath('.//@href')[0]
                link = base_url + href
                if link not in results: 
                    results.append(link)
        return results

# %%
scraper = Scraper(url)
films = scraper.get_all_films()

# %%
class Film_Scraper(Scraper): 
    def __init__(self, url): 
        super().__init__(url)
    def get_film_info(self):
        screenings = []
        film = {}   
        driver = webdriver.Chrome(executable_path=CHROMEDRIVER_PATH)
        driver.get(self.url)
        times = driver.find_elements_by_xpath('//div[contains(@class, "my-account-content")]//a[@class="btn btn-primary"]')
#         for time in times: 
#             date = driver.find_element_by_xpath('//a[@href="{}"]/ancestor::div[@class="shortcodes_content"]/h6/text()'.format(film['link']))
#             film['link'] = time.get_attribute('href')
#             film['time'] = time
#             film['date'] = date
#             film['film'] = {}
#             film['film']['title'] = driver.find_element_by_xpath('//h4/text()')[0].strip()
#             film['film']['poster'] = driver.find_element_by_xpath('//a[@data-toggle="lightbox"]/@href')[0]
#             film['film']['duration'] = driver.find_element_by_xpath('//h6[text()="Duración"]/following-sibling::p/text()')[0]
#             film['film']['director'] = driver.find_element_by_xpath('//h6[text()="Dirección"]/following-sibling::p/text()')[0]
#             film['film']['cast'] = driver.find_element_by_xpath('//h6[text()="Intérpretes"]/following-sibling::p/text()')[0]
#             film['film']['original_language'] = driver.find_element_by_xpath('//h6[text()="Idioma original"]/following-sibling::p/text()')[0]
#             film['film']['language'] = time.find_element_by_xpath('//a[@href="{}"]/ancestor::div[@class="row"]//small/text()'.format(film['link']))
#             film['cinema'] = {}
#             film['cinema']['name'] = 'Renoir Floridablanca'
#             film['cinema']['barri'] = 'Sant Antoni'
#             film['cinema']['address'] = 'Carrer de Floridablanca, 135, 08011 Barcelona, Spain'
#             screenings.append(film)
        driver.quit()
        return [time.get_attribute('href') for time in times]

# %%
film_scraper = Film_Scraper(films[2])
test = film_scraper.get_film_info()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python38\site-packages\urllib3\connection.py in _new_conn(self)
#     155         try:
# --> 156             conn = connection.create_connection(
#     157                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\AppData\Roaming\Python\Python38\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# ~\AppData\Roaming\Python\Python38\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# ...

# %%
test[0]
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python38\site-packages\urllib3\connection.py in _new_conn(self)
#     155         try:
# --> 156             conn = connection.create_connection(
#     157                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\AppData\Roaming\Python\Python38\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# ~\AppData\Roaming\Python\Python38\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# ...
